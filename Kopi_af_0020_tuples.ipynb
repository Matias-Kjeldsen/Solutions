# %% [markdown]
# <a href="https://colab.research.google.com/github/Matias-Kjeldsen/Solutions/blob/Rep/Kopi_af_0020_tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Tupler (tuples)

# %% [markdown]
# Tupler tillader dig at oprette uforanderlige grupper af objekter.
# Dette betyder, at når en tupel er oprettet, kan den ikke ændres. Du kan ikke tilføje eller fjerne elementer.
#
# De oprettes på en måde, der ligner lister, men ved brug af parenteser i stedet for kantede parenteser:

# %%
names = ("Hans", "Gitte")

# %% [markdown]
# En tupel er ordnet, ligesom en liste, så du kan få dens værdier ved at referere til en indeksværdi:

# %%
print(f"{names[0] = }")
print(f"{names[1] = }")
# Out:
# names[0] = 'Hans'
# names[1] = 'Gitte'

# %% [markdown]
# Som med lister kan du også bruge `index()`-funktionen til tupler.

# %%
print(f"{names.index('Hans') = }")
print(f"{names.index('Gitte') = }")
# Out:
# names.index('Hans') = 0
# names.index('Gitte') = 1

# %% [markdown]
# Som med strings og lister vil brug af et negativt indeks starte søgningen fra slutningen:

# %%
print(f"{names[-1] = }")
# Out:
# names[-1] = 'Gitte'

# %% [markdown]
# Du kan også tælle elementerne i en tupel med `len()`-funktionen, ligesom med lister.:

# %%
print(f"{len(names) = }")
# Out:
# len(names) = 2

# %% [markdown]
# Som med lister kan du tjekke, om et element er indeholdt i en tupel med `in`-operatoren:

# %%
print(f'{"Hans" in names = }')
# Out:
# "Hans" in names = True

# %% [markdown]
# Du kan også udtrække en del af en tupel ved hjælp af slices:

# %%
print(f"{names[0:2] = }")
print(f"{names[1:] = }")
# Out:
# names[0:2] = ('Hans', 'Gitte')
# names[1:] = ('Gitte',)

# %% [markdown]
# Du kan oprette en sorteret version af en tupel ved hjælp af den globale funktion `sorted()`:

# %%
# sorted(names)
print(f"{sorted(names) = }")
# Out:
# sorted(names) = ['Gitte', 'Hans']

# %% [markdown]
# Du kan oprette en ny tupel fra eksisterende tupler ved hjælp af `+`-operatoren:

# %%
newTuple = names + ("Susi", "Tony")
print(f"{newTuple = }")
# Out:
# newTuple = ('Hans', 'Gitte', 'Susi', 'Tony')

# %% [markdown]
# ### Øvelser

# %%
number_tuple = (18, 22, 7)
print(f"{number_tuple = }")
# Out:
# number_tuple = (18, 22, 7)

# %% [markdown]
# Udfør de næste celler en af gangen. Før du udfører en celle, regn resultatet ud på forhånd. Når du får et uventet resultat, find ud af hvorfor.
# Leg gerne med cellerne. Forandre dem og udfør dem igen. Du kan også tilføje nye celler.

# %%
print(f"{type(number_tuple) = }")
# Out:
# type(number_tuple) = <class 'tuple'>

# %%
print(f"{len(number_tuple) = }")
# Out:
# len(number_tuple) = 3

# %%
print(f"{22 in number_tuple = }")
# Out:
# 22 in number_tuple = True

# %%
x1 = number_tuple[0]
print(f"{x1 = }")
# Out:
# x1 = 18

# %%
print(f"{type(x1) = }")
# Out:
# type(x1) = <class 'int'>

# %%
x2 = number_tuple[0:1]
print(f"{x2 = }")
# Out:
# x2 = (18,)

# %%
print(f"{type(x2) = }")
# Out:
# type(x2) = <class 'tuple'>

# %%
new_tuple = number_tuple + number_tuple
print(f"{new_tuple = }")
# Out:
# new_tuple = (18, 22, 7, 18, 22, 7)

# %% [markdown]
# Forstod/løste du alle opgaver på denne side?
# Ellers spørg [W3schools](https://www.w3schools.com/python/), [Google](https://www.google.com),
# [Perplexity](https://perplexity.ai), andre elever eller læreren.
#
# Arbejd videre med den næste Jupyter Notebook.
