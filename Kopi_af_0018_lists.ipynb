# %% [markdown]
# <a href="https://colab.research.google.com/github/Matias-Kjeldsen/Solutions/blob/Rep/Kopi_af_0018_lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Lister (lists)

# %% [markdown]
# Lister tillader dig at gruppere flere værdier sammen og referere til dem alle med et fælles navn:

# %%
names = ["Hans", "Gitte"]

# %% [markdown]
# En liste kan indeholde værdier af forskellige typer:

# %%
items = ["Hans", 1, "Gitte", True]

# %% [markdown]
# Du kan tjekke, om et element er indeholdt i en liste med `in`-operatoren.
#
# (Husk at udføre den forrige celle, før du udfører den næste, ellers er variablen `items` ikke defineret, og du vil få en fejlmeddelelse.)

# %%
print("Hans" in items)
# Out:
# True

# %% [markdown]
# En liste kan også defineres som tom:

# %%
empty_list = []
print(f"{empty_list = }")
# Out:
# empty_list = []

# %% [markdown]
# Du kan referere til elementerne i en liste ved deres indeks, startende fra nul:

# %%
print(f"{items[0] = }")
print(f"{items[1] = }")
print(f"{items[3] = }")
# Out:
# items[0] = 'Hans'
# items[1] = 1
# items[3] = True

# %% [markdown]
# Ved at bruge samme notation kan du ændre værdien gemt på et specifikt indeks:

# %%
items[0] = "Jesper"
print(f"{items = }")
# Out:
# items = ['Jesper', 1, 'Gitte', True]

# %% [markdown]
# Ligesom med strenge vil brug af et negativt indeks starte søgningen fra slutningen:

# %%
print(f"{items[-1] = }")
# Out:
# items[-1] = True

# %% [markdown]
# Du kan også udtrække en del af en liste ved hjælp af _slices_:

# %%
print(f"{items[0:2] = }")
print(f"{items[2:] = }")
# Out:
# items[0:2] = ['Jesper', 1]
# items[2:] = ['Gitte', True]

# %% [markdown]
# Få antallet af elementer i en liste ved hjælp af funktionen `len()`, den samme vi brugte til at få længden af en streng:

# %%
print(f"{len(items) = }")
# Out:
# len(items) = 4

# %% [markdown]
# Du kan tilføje elementer til listen ved at bruge listens `append()`-metode:

# %%
items.append("Test")
print(f"{items = }")
# Out:
# items = ['Jesper', 1, 'Gitte', True, 'Test']

# %% [markdown]
# Eller brug `extend()`-metoden hvis du vil tilføje flere elementer samtidigt:

# %%
items.extend([33, 44, "Hej"])
print(f"{items = }")
# Out:
# items = ['Jesper', 1, 'Gitte', True, 'Test', 33, 44, 'Hej']

# %% [markdown]
# Du kan også bruge `+=`-operatoren:

# %%
items += ["xxx"]
print(f"{items = }")
# Out:
# items = ['Jesper', 1, 'Gitte', True, 'Test', 33, 44, 'Hej', 'xxx']

# %% [markdown]
# Fjern et element ved hjælp af `remove()`-metoden:

# %%
items.remove("Test")
items.remove(33)
items.remove("Gitte")
print(f"{items = }")  # removes the first element which is equal to "Test"
# Out:
# items = ['Jesper', 1, True, 44, 'Hej', 'xxx']

# %% [markdown]
# Funktionen `index` giver dig indekset for den første forekomst af en element i listen:

# %%
items.index('Hej')
# Out:
# 4

# %% [markdown]
# `append`, `extend` og `+=` tilføjer elementer til slutningen af listen.
#
# For at tilføje et element i midten af en liste, på et specifikt indeks, skal du bruge `insert()`-metoden:

# %%
items.insert(2, "Test") # tilføj "Test" ved indeks 2
print(f"{items = }")
# Out:
# items = ['Jesper', 1, 'Test', True, 44, 'Hej', 'xxx']

# %% [markdown]
# Sortér en liste ved hjælp af `sort()`-metoden:

# %%
some_numbers = [2, 6, 1, 18, 4, -3]
print(f"Before: {some_numbers = }")
some_numbers.sort()
print(f"After:  {some_numbers = }")
# Out:
# Before: some_numbers = [2, 6, 1, 18, 4, -3]
# After:  some_numbers = [-3, 1, 2, 4, 6, 18]

# %% [markdown]
# Tip: `sort()` vil kun virke, hvis listen indeholder værdier, der kan sammenlignes. Strenge og heltal kan for eksempel ikke sammenlignes, og du vil få en fejl som `TypeError: '<' not supported between instances of 'int' and 'str'` hvis du prøver.

# %% [markdown]
# Sortering med `.sort` ændrer det originale listeindhold. For at undgå dette kan du bruge funktionen `sorted()`, som vil returnere en ny, sorteret liste i stedet for at ændre den originale liste:

# %%
other_numbers = [7, 1, -4, 6]
print(f"Before: {other_numbers = }")
print(f"{sorted(other_numbers) = }")
print(f"After: {other_numbers = }")
# Out:
# Before: other_numbers = [7, 1, -4, 6]
# sorted(other_numbers) = [-4, 1, 6, 7]
# After: other_numbers = [7, 1, -4, 6]

# %% [markdown]
# En string i Python er teknisk set en liste af tegn.
#
# Derfor kan du få uventede resultater, hvis du føjer en string til en liste med `extend()` eller `+=`.

# %%
some_list = ["Hans"]
some_list += "Gitte" # add a string to some_list
print(some_list)
# Out:
# ['Hans', 'G', 'i', 't', 't', 'e']

# %% [markdown]
# `"Gitte"` er en string og betragtes af `+=` som en liste af tegn.
#
# Men `["Gitte"]` er en liste, som indeholder én string.

# %%
another_list = ["Hans"]
another_list += ["Gitte"]  # add a list which contains a string to another_list
print(another_list)
# Out:
# ['Hans', 'Gitte']

# %% [markdown]
# ### Øvelser

# %%
numbers = [5, -2, 4, 17]
print(f"{numbers = }")
# Out:
# numbers = [5, -2, 4, 17]

# %% [markdown]
# Udfør de næste celler en af gangen. Før du udfører en celle, regn resultatet ud på forhånd. Når du får et uventet resultat, find ud af hvorfor.
# Leg gerne med cellerne. Forandre dem og udfør dem igen. Du kan også tilføje nye celler.

# %%
print(f"{type(numbers) = }")
# Out:
# type(numbers) = <class 'list'>

# %%
print(f"{len(numbers) = }")
# Out:
# len(numbers) = 4

# %%
print(f"{17 in numbers = }")
# Out:
# 17 in numbers = True

# %%
print(f"{2 in numbers = }")
# Out:
# 2 in numbers = False

# %%
print(f"{numbers[0] = }")
# Out:
# numbers[0] = 5

# %%
print(f"{numbers[3] = }")
# Out:
# numbers[3] = 17

# %%
print(f"{numbers[-1] = }")
# Out:
# numbers[-1] = 17

# %%
print(f"{numbers[:2] = }")
# Out:
# numbers[:2] = [5, -2]

# %%
print(f"{numbers[2:] = }")
# Out:
# numbers[2:] = [4, 17]

# %%
numbers.append(9)
numbers.append(5)
print(f"{numbers = }")
# Out:
# numbers = [5, -2, 4, 17, 9, 5]

# %%
print(f"{numbers[2:] = }")
# Out:
# numbers[2:] = [4, 17, 9, 5]

# %%
print(f"{len(numbers) = }")
# Out:
# len(numbers) = 6

# %%
print(f"{sorted(numbers) = }")
# Out:
# sorted(numbers) = [-2, 4, 5, 5, 9, 17]

# %%
print(f"{numbers = }")
# Out:
# numbers = [5, -2, 4, 17, 9, 5]

# %%
numbers.sort()
print(f"{numbers = }")
# Out:
# numbers = [-2, 4, 5, 5, 9, 17]

# %% [markdown]
# Tilføj kode til de følgende celler, sådan at resultatet bliver den udtryk i kommentaren.

# %%
print(f"{numbers[1] = }")  # 4
# Out:
# numbers[1] = 4

# %%
print(f"{numbers[-1] = }")  # 17
# Out:
# numbers[-1] = 17

# %%
print(f"{numbers[2:4] = }")  # [5, 5]
# Out:
# numbers[2:4] = [5, 5]

# %%
print(f"{numbers[3:] = }")  # [5, 9, 17]
# Out:
# numbers[3:] = [5, 9, 17]

# %%
numbers.append(3)
print(f"{numbers[:] = }")  # [-2, 4, 5, 5, 9, 17, 3]
# Out:
# numbers[:] = [-2, 4, 5, 5, 9, 17, 3, 3, 3, 3, 3, 3, 3]

# %% [markdown]
# Forstod/løste du alle opgaver på denne side?
# Ellers spørg [W3schools](https://www.w3schools.com/python/), [Google](https://www.google.com),
# [Perplexity](https://perplexity.ai), andre elever eller læreren.
#
# Arbejd videre med den næste Jupyter Notebook.
